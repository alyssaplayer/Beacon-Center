# %%
import pandas as pd

# %%
assay_data = pd.read_csv("20250703_LlamaVHH_AssayData_1029Candidates.csv", sep=",")

# %%
assay_data.head()
# Out:
#   ChipId,PenId,Assay_1_CY5 : IsPositiveVerified,Assay_1_DAPI : IsPositiveVerified,Assay_1_FITC : IsPositiveVerified,Assay_1_PE : IsPositiveVerified,Assay_1_TRED : IsPositiveVerified,Assay_2_CY5 : IsPositiveVerified,Assay_2_DAPI : IsPositiveVerified,Assay_2_FITC : IsPositiveVerified,Assay_2_PE : IsPositiveVerified,Assay_2_TRED : IsPositiveVerified,Assay_3_CY5 : IsPositiveVerified,Assay_3_FITC : IsPositiveVerified,Assay_4_CY5 : IsPositiveVerified,Assay_4_DAPI : IsPositiveVerified,Assay_4_FITC : IsPositiveVerified,Assay_4_PE : IsPositiveVerified,Assay_4_TRED : IsPositiveVerified,Assay_5_CY5 : IsPositiveVerified,Assay_5_DAPI : IsPositiveVerified,Assay_5_FITC : IsPositiveVerified,Assay_5_PE : IsPositiveVerified,Assay_5_TRED : IsPositiveVerified,export1 : CellType,export1 : NumCellsUnpenned,export1 : WellColumn,export1 : WellPlateID,export1 : WellRow,Load : CellCount,
# 0  D125987,1690,TRUE,TRUE,FALSE,TRUE,TRUE,TRUE,TR...
# 1  D125987,12381,TRUE,TRUE,FALSE,TRUE,TRUE,TRUE,T...
# ...

# %%
target_ids = [9731, 12546, 13761, 16251, 19868, 18336, 794, 1843, 3897, 4118]
xfect_candidates = assay_data[assay_data['PenId'].isin(target_ids)]

# %%
print(xfect_candidates)
# Out:
#       ChipId  PenId  Assay_1_CY5 : IsPositiveVerified  \
# 68   D125987   9731                              True
# 74   D125987  13761                              True
# 80   D125987  12546                              True
# 95   D125987  16251                              True
# 106  D125987  19868                              True
# 115  D125987  18336                             False
# 126  D125987    794                             False
# 140  D125987   1843                              True
# 171  D125987   4118                             False
# 175  D125987   3897                              True
#
#      Assay_1_DAPI : IsPositiveVerified  Assay_1_FITC : IsPositiveVerified  \
# 68                               False                               True
# 74                                True                               True
# 80                               False                               True
# ...

# %%
xfect_candidates.to_csv('Llama VHH Candidates 1029 Assay Data.csv', index=False)
